# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

print(os.getcwd())
data_path = os.path.join(os.getcwd(), 'data\\Training_Data_Traffic_Signs\\')
# Out:
# e:\OneDrive_Imperial_College_London\College\My\Some_projects\datathon

# %%
df_train = pd.read_csv(os.path.join(data_path, 'Train.csv'))
df_train.sample(5)
# Out:
#        Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 34409     25      26       5       5      20      20       35
# 5446      41      39       6       5      35      34        3
# 19780     47      50       6       6      41      44       12
# 12096     30      29       5       5      25      24        7
# 9906      32      34       5       6      27      29        5
#
#                                  Path
# 34409  Train/35/00035_00007_00000.png
# 5446    Train/3/00003_00013_00016.png
# 19780  Train/12/00012_00047_00010.png
# 12096   Train/7/00007_00046_00006.png
# 9906    Train/5/00005_00049_00006.png

# %%
heights = df_train['Height']
widths = df_train['Width']

# %%
one_img = df_train.sample(9)['Path']

# %%
for i in range(9):
    img = tf.io.read_file(data_path+one_img.iloc[i])
    img_tensor = tf.io.decode_png(img, channels=3)
    plt.subplot(3,3,i+1)
    plt.imshow(img_tensor)

# %%
def load_and_resize_image(filepath, shape):
    """
    Loads and resizes an image from a filepath.
    """
    raw_img = tf.io.read_file(filepath)
    img_tensor = tf.io.decode_png(raw_img, channels=3)
    img_tensor = tf.image.resize(img_tensor, tf.constant(shape[:2]))
    return img_tensor

# %%
plt.imshow(load_and_resize_image(data_path+one_img.iloc[0], (, 224, 3)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
